# %% [markdown]
# # Assigment 9: Ejercicio completo de data frames

# %% [markdown]
# *Carga el CSV de la carpeta de datos del tema llamado run.csv y responde a las siguientes preguntas.*

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("../data/run.csv", index_col= [0])
df
# Out:
#     pulso.antes  pulso.despues hace.deporte fuma genero  altura  peso  \
# 1            48             54           no   si      H    68.0   150
# 2            54             56           no   si      H    69.0   145
# 3            54             50           no   no      H    69.0   160
# 4            58             70           si   no      H    72.0   145
# 5            58             58           no   no      H    66.0   135
# ..          ...            ...          ...  ...    ...     ...   ...
# 88           92             94           no   si      H    69.0   150
# 89           94             92           no   si      M    62.0   131
# 90           96            140           si   no      M    61.0   140
# 91           96            116           si   no      M    68.0   116
# 92          100            115           si   si      M    63.0   121
#
#    tipo.actividad
# 1            nula
# 2        moderada
# 3        moderada
# 4        moderada
# 5         intensa
# ..            ...
# 88       moderada
# 89       moderada
# 90       moderada
# 91       moderada
# 92       moderada
#
# [92 rows x 8 columns]

# %% [markdown]
# *1.Indica cuantos estudiantes formaron parte del estudio de deporte*

# %%
df.shape # en total fueron 92 estudiantes
# Out:
# (92, 8)

# %% [markdown]
# *2. Indica cuantos individuos son hombres y cuantos son mujeres*

# %%
df.groupby('genero').count() # 57 hombres y 35 mujeres
# Out:
#         pulso.antes  pulso.despues  hace.deporte  fuma  altura  peso  \
# genero
# H                57             57            57    57      57    57
# M                35             35            35    35      35    35
#
#         tipo.actividad
# genero
# H                   57
# M                   35

# %% [markdown]
# *3.Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio y compara el valor de los que hacen ejercicio habitualmente y los que no. ¿Observas mucha diferencia?*

# %%
df.groupby('hace.deporte').mean()  # entre los que no hacen deporrte no har diferencia, lo contrario entre los que sí hacen dep.
# Out:
#               pulso.antes  pulso.despues     altura        peso
# hace.deporte
# no              72.421053      72.315789  68.065789  141.122807
# si              73.600000      92.514286  69.778571  151.714286

# %%
# Voy a crear una nueva variable llamada variacion media

df['var.por.media'] = (df['pulso.despues'] - df['pulso.antes'])/ df['pulso.antes'] * 100
df.head(4)

df3 = df.groupby('hace.deporte').mean()
df3
# Out:
#               pulso.antes  pulso.despues     altura        peso  var.por.media
# hace.deporte
# no              72.421053      72.315789  68.065789  141.122807       0.209479
# si              73.600000      92.514286  69.778571  151.714286      26.215407

# %% [markdown]
# *4. Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio  para los estudiantes que hacen ejercicio habitualmente y compara el valor de los hombres con el de las mujeres. ¿Observas mucha diferencia?*

# %%
df2 = df.rename(columns = {'hace.deporte': 'hacedeporte'})
df2.groupby(['hacedeporte','genero']).mean()  

# las mujeres tienen el doble de porcentaje de variación que los hombre
# Out:
#                     pulso.antes  pulso.despues     altura        peso  \
# hacedeporte genero
# no          H         70.545455      70.545455  70.409091  155.545455
#             M         75.000000      74.750000  64.843750  121.291667
# si          H         70.250000      83.208333  71.229167  162.000000
#             M         80.909091     112.818182  66.613636  129.272727
#
#                     var.por.media
# hacedeporte genero
# no          H            0.249970
#             M            0.153805
# si          H           19.176886
#             M           41.572181

# %% [markdown]
# *5. Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio para los estudiantes que no hacen ejercicio habitualmente y compara el valor de los fumadores con los no fumadores. ¿Observas mucha diferencia?*

# %%
df2.groupby(['hacedeporte','fuma']).mean()  # no, no hya mucha diferencia. esta no excede, en promedio, ni el 1%.
# Out:
#                   pulso.antes  pulso.despues     altura        peso  \
# hacedeporte fuma
# no          no      71.707317      71.512195  68.079268  138.195122
#             si      74.250000      74.375000  68.031250  148.625000
# si          no      72.347826      93.695652  69.478261  148.869565
#             si      76.000000      90.250000  70.354167  157.166667
#
#                   var.por.media
# hacedeporte fuma
# no          no        -0.064761
#             si         0.912219
# si          no        29.412181
#             si        20.088258

# %% [markdown]
# *6. Calcula el porcentaje medio de variación del pulso por minuto entre antes y después de hacer ejercicio de todos los estudiantes según el tipo de actividad física que realizan. ¿Observas alguna diferencia?*

# %%
df2.groupby('tipo.actividad').mean()  # los que tienen mayor variación promedio son los que tienen nula y moderada, mientras que los que varían menos que el 4% son los de actividad intensa y suave
# Out:
#                 pulso.antes  pulso.despues     altura        peso  \
# tipo.actividad
# intensa           71.571429      72.190476  69.571429  147.285714
# moderada          72.737705      82.786885  68.377049  143.754098
# nula              48.000000      54.000000  68.000000  150.000000
# suave             79.555556      82.222222  69.111111  149.111111
#
#                 var.por.media
# tipo.actividad
# intensa              1.347475
# moderada            14.015695
# nula                12.500000
# suave                3.747241

# %%
df4 = df2[df2['hacedeporte'] == 'si']
df4
# Out:
#     pulso.antes  pulso.despues hacedeporte fuma genero  altura  peso  \
# 4            58             70          si   no      H   72.00   145
# 7            60             76          si   no      H   71.00   170
# 12           62             76          si   si      H   73.50   160
# 13           62             75          si   no      H   72.00   195
# 14           62             58          si   no      H   72.00   175
# 15           62            100          si   no      M   66.00   120
# 16           62             98          si   si      M   62.75   112
# 21           64             88          si   no      H   66.00   140
# 22           64             80          si   no      H   69.00   155
# 25           66             78          si   si      H   73.00   190
# 26           66             82          si   si      H   69.00   175
# 27           66            102          si   no      H   70.00   130
# 30           68             72          si   no      H   74.00   190
# 31           68             76          si   no      H   67.00   145
# 32           68             76          si   si      H   74.00   180
# 33           68            112          si   no      M   70.00   125
# 41           70             72          si   si      H   73.00   170
# 42           70            106          si   no      H   71.00   170
# 43           70             94          si   si      H   75.00   185
# 47           72             80          si   no      H   66.00   135
# 53           74             84          si   no      H   73.00   165
# 54           74             76          si   no      H   70.00   157
# 58           76            118          si   no      H   71.00   138
# 63           78            104          si   si      M   68.00   130
# 64           78            118          si   no      M   69.00   145
# 68           80             96          si   no      H   72.00   155
# 69           80            128          si   no      M   68.00   125
# 71           82            100          si   no      M   68.00   138
# 74           84             84          si   no      H   72.00   150
# 80           88            110          si   si      M   69.00   150
# 83           90             94          si   si      H   74.00   160
# 87           92             84          si   si      H   70.00   153
# 90           96            140          si   no      M   61.00   140
# 91           96            116          si   no      M   68.00   116
# 92          100            115          si   si      M   63.00   121
#
#    tipo.actividad  var.por.media
# 4        moderada      20.689655
# 7         intensa      26.666667
# 12        intensa      22.580645
# 13       moderada      20.967742
# 14        intensa      -6.451613
# 15       moderada      61.290323
# 16       moderada      58.064516
# 21       moderada      37.500000
# 22       moderada      25.000000
# 25          suave      18.181818
# 26       moderada      24.242424
# 27       moderada      54.545455
# 30       moderada       5.882353
# 31       moderada      11.764706
# 32       moderada      11.764706
# 33       moderada      64.705882
# 41        intensa       2.857143
# 42       moderada      51.428571
# 43       moderada      34.285714
# 47        intensa      11.111111
# 53          suave      13.513514
# 54       moderada       2.702703
# 58       moderada      55.263158
# 63       moderada      33.333333
# 64       moderada      51.282051
# 68       moderada      20.000000
# 69       moderada      60.000000
# 71       moderada      21.951220
# 74        intensa       0.000000
# 80       moderada      25.000000
# 83          suave       4.444444
# 87        intensa      -8.695652
# 90       moderada      45.833333
# 91       moderada      20.833333
# 92       moderada      15.000000
